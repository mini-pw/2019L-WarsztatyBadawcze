# %%
import os
import pandas as pd
import json
import time

# %%
df = pd.DataFrame()

# %%
for dataset in os.listdir():
    if os.path.isdir(dataset) and not dataset.startswith("."):
#         print(dataset)
        for task in os.listdir(dataset):
            if os.path.isdir(os.path.join(dataset, task)) and not task.startswith("."):
                with open(os.path.join(dataset, "dataset.json"), 'r') as f:
                    dataset_info = json.load(f)
                    dataset_info = dict([(key, dataset_info[0][key]) for key in 
                                         ['number_of_features',
                                          'number_of_instances',
                                          'number_of_missing_values',
                                          'number_of_instances_with_missing_values']])
#                     print(dataset_info)            
#                     print("\t", task)

                    # na razie wyrozniam tylko klasyfikacje
                    if not task.startswith("classification"):
                        continue
                    for model in os.listdir(os.path.join(dataset, task)):
                        try:
                            if os.path.isdir(os.path.join(dataset, task, model)):
#                                 print("\t\t", model)

                                with open(os.path.join(dataset, task, model, "audit.json")) as fa:
                                    audit_info = json.load(fa)
                                    audit_info = dict([(metrics, audit_info[0]['performance'][metrics]) 
                                                       for metrics in ['acc', 
                                                                       'auc',
                                                                       'specificity',
                                                                       'recall', 
                                                                       'precision',
                                                                       'f1']])
#                                     print(audit_info)
                                with open(os.path.join(dataset, task, model, "model.json")) as fm:
                                    model_info = json.load(fm)
                                    model_info = dict([(key, model_info[0][key]) 
                                                      for key in ['id',
                                                                  'library',
                                                                  'model_name']])
#                                     print(model_info)

                                model = dataset_info
                                model.update(audit_info)
                                model.update(model_info)
                                model = pd.DataFrame.from_dict(model, orient='index').T
                                df = df.append(model)
                        except :
                            continue

# %%
df
# Out:
#    number_of_features number_of_instances number_of_missing_values  \
# 0                   4                 306                        0
# 0                   4                 306                        0
# 0                   4                 306                        0
# 0                   4                 306                        0
# 0                   4                 306                        0
# 0                   4                 306                        0
# 0                   4                 306                        0
# 0                   4                 306                        0
# 0                   4                 306                        0
# 0                   4                 306                        0
# 0                   4                 306                        0
# 0                   4                 306                        0
# 0                  14                 100                        0
# 0                  12                 800                      387
# 0                  12                 800                      387
# 0                  12                 800                      387
# 0                  12                 800                      387
# 0                   9               17898                        0
# 0                   6              150000                        0
# 0                   6              150000                        0
# 0                   6              150000                        0
# 0                   8               10218                        0
# 0                   8               10218                        0
# 0                   8               10218                        0
# 0                   8               10218                        0
# 0                   8               10218                        0
# 0                   8               10218                        0
# 0                   8               10218                        0
# 0                   8               10218                        0
# 0                   8               10218                        0
# ..                ...                 ...                      ...
# 0                  36                 683                     2337
# 0                  10                 950                        0
# 0                  14                 178                        0
# 0                  14                 178                        0
# 0                  14                 178                        0
# 0                  14                 178                        0
# 0                  14                 178                        0
# 0                  12                4898                        0
# 0                  12                4898                        0
# 0                  12                4898                        0
# 0                  12                4898                        0
# 0                  12                4898                        0
# 0                  12                4898                        0
# 0                  12                4898                        0
# 0                  12                4898                        0
# 0                  12                4898                        0
# 0                  12                4898                        0
# 0                  12                4898                        0
# 0                  12                4898                        0
# 0                  12                4898                        0
# 0                  12                4898                        0
# 0                  12                4898                        0
# 0                  12                4898                        0
# 0                  12                4898                        0
# 0                  12                4898                        0
# 0                  12                4898                        0
# 0                  18                 101                        0
# 0                   9                4177                        0
# 0                   9                4177                        0
# 0                  19                2310                        0
#
#    number_of_instances_with_missing_values       acc       auc specificity  \
# 0                                        0  0.696298  0.697962    0.309341
# 0                                        0  0.826087  0.674342    0.921053
# 0                                        0  0.826087  0.751645    0.947368
# 0                                        0  0.847826  0.689145    0.947368
# 0                                        0  0.826087  0.717105    0.921053
# 0                                        0  0.826087  0.720395    0.921053
# 0                                        0  0.717391  0.634033    0.939394
# 0                                        0  0.826087  0.707237    0.921053
# 0                                        0  0.826087  0.682566    0.921053
# 0                                        0  0.826087  0.671053    0.921053
# 0                                        0  0.826087  0.669408    0.921053
# 0                                        0  0.847826  0.708882    0.947368
# 0                                        0  0.752131      None        None
# 0                                      386    0.9397    0.9644      0.5175
# 0                                      386    0.9203    0.9527      0.3738
# 0                                      386    0.9204    0.9538      0.5663
# 0                                      386    0.9324    0.9399      0.5724
# 0                                        0  0.978378      None        None
# 0                                        0    0.6722    0.7286      0.8131
# 0                                        0    0.6739    0.7239      0.8089
# 0                                        0    0.6951    0.7589      0.7716
# 0                                        0  0.846056      None        None
# 0                                        0  0.226366      None        None
# 0                                        0    0.3417      None        None
# 0       None      None      None   7a667d0fe29687f2462e4d00b2d1c587     mlr
# 0       None      None      None   7d1e71e7e7a35c5650176983941e5fa8     mlr
# 0       None      None      None   9940fbff9ab2f678717a841c9940123c     mlr
# 0       None      None      None   cc0d522bd7ee1e2497597a0522760530     mlr
# ..       ...       ...       ...                                ...     ...
# 0       None      None      None   efaf17cd6974bb344011d72e65d5e257     mlr
# 0     0.9709    0.9711    0.9709   23f6915be2c5eae872fb2a6e6e375f50     mlr
# 0       None      None      None   08acd2132d3785383b3191e00f5f994e     mlr
# 0       None      None      None   92b5d0bc0370dcdd369ca5a0c4ef85c6     mlr
# 0       None      None      None   c59a1ff9956ecfe018adeb377c6ed350     mlr
# 0       None      None      None   f4da2d66722ed637faed3cae1a03d6eb     mlr
# 0       None      None      None   ff348862134c483faa16e0c6c9afae4c     mlr
# 0       None      None      None   1eaedcc17551457477f1ab78e92b1bef     mlr
# 0       None      None      None   2774743c48dbe50368402b9aca192ad8     mlr
# 0       None      None      None   2baa476371522759b147c326e694dad5     mlr
# 0       None      None      None   41dcd6bb9d78a1b73534ad481ae918a9     mlr
# 0       None      None      None   444c36bb28d0c2362bfef696a01a3429     mlr
# 0       None      None      None   56a96a6662aa8c7bee3d8b6d39c7e9dd     mlr
# 0       None      None      None   673e131d953865009c54ad56513e7659     mlr
# 0       None      None      None   6ee9b97ec15be3f8cf66e3437536e33b     mlr
# 0       None      None      None   6fb9354c4e771dee6cda49eed09a1ad8     mlr
# 0       None      None      None   72486a4ac1fe2098ebd5f3b3ccf62ac1     mlr
# 0       None      None      None   7c22544e540634b861e8c992645773fd     mlr
# 0       None      None      None   941d1d9a888e2580f439309dfa99fc88     mlr
# 0       None      None      None   a12b67db6fec572aaa1a39fd9a3a4294     mlr
# 0       None      None      None   a526eb647448da0539796972dc75eedf     mlr
# 0       None      None      None   e134cdc9d0e49c413970c5e0ace75663     mlr
# 0       None      None      None   e2f900123067e64382a90c6a771e6f82     mlr
# 0       None      None      None   e811552c86e0351f1bfc2303dc45bac5     mlr
# 0       None      None      None   ef98a349ad29b6d70316c2aeb8156a6a   caret
# 0       None      None      None   f1ac3e3591b3a882a2671d6a6c8eea85     mlr
# 0     0.9555    0.9259    0.9402   147da89c2ea06175928b517c966f7594     mlr
# 0       None      None      None   0a342b9b7f65a057115b701123e06f26   caret
# 0       None      None      None   39d6ac02d37385aa5f665bfad6e92a56     mlr
# 0       None      None      None   33dd7dad1fb2f36c82f3a0dfe2052aac     mlr
#
#                                     model_name
# 0                      classif.randomForestSRC
# 0                         KNeighborsClassifier
# 0                         KNeighborsClassifier
# 0                         KNeighborsClassifier
# 0                         KNeighborsClassifier
# 0                         KNeighborsClassifier
# 0                         KNeighborsClassifier
# 0                         KNeighborsClassifier
# 0                         KNeighborsClassifier
# 0                         KNeighborsClassifier
# 0                         KNeighborsClassifier
# 0                         KNeighborsClassifier
# 0                         classif.randomForest
# 0                                  classif.svm
# 0                                  classif.gbm
# 0                                  classif.rda
# 0                                  classif.mda
# 0                                         kknn
# 0                                  classif.gbm
# 0                                  classif.gbm
# 0                                  classif.gbm
# 0                         classif.randomForest
# 0                                       glmnet
# 0                                  classif.lda
# 0                                  classif.lda
# 0                             classif.cvglmnet
# 0                             classif.cvglmnet
# 0                                 classif.kknn
# 0                                  classif.lda
# 0                           classif.naiveBayes
# ..                                         ...
# 0                         classif.randomForest
# 0                                 classif.rknn
# 0                           classif.naiveBayes
# 0                         classif.randomForest
# 0                                  classif.svm
# 0                                 classif.kknn
# 0                             classif.multinom
# 0                                  classif.fnn
# 0                               classif.ranger
# 0                               classif.ranger
# 0                               classif.ranger
# 0                               classif.ranger
# 0                               classif.ranger
# 0                               classif.ranger
# 0                               classif.ranger
# 0                               classif.ranger
# 0                               classif.ranger
# 0                               classif.ranger
# 0                               classif.ranger
# 0                           classif.extraTrees
# 0                               classif.ranger
# 0                               classif.ranger
# 0                               classif.ranger
# 0                               classif.ranger
# 0                                          LMT
# 0                             classif.boosting
# 0                                  classif.ada
# 0            Regularized Discriminant Analysis
# 0   Training Neural Network by Backpropagation
# 0                                Random Forest
#
# [269 rows x 13 columns]
